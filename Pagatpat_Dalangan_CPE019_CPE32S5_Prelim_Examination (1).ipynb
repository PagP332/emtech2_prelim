# %% [markdown]
# Choose any dataset applicable for classification and/or prediction analysis problems.
#
# Show the application of the following algorithms:
#
# * Linear Regression
#
#  * Singular LR
#
#  * Multiple LR
#
#  * Polynomial LR
#
# * Logistic Regression
#
# * Decision Tree
#
# * Random Forest
#
# Provide Evaluation reports for all models

# %%
# Import the CSV file
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

appleDF = pd.read_csv('/content/drive/MyDrive/CPE019_prelim/apple_quality.csv')
appleDF.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1     1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2     2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3     3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#     Acidity Quality
# 0 -0.491590    good
# 1 -0.722809    good
# 2  2.621636     bad
# 3  0.790723    good
# 4  0.501984    good

# %%
# Change labels of Quality from good and bad to 1 and 0 respectively for data analysis
appleDF["Quality"] = appleDF["Quality"].apply(lambda toLabel: 0 if toLabel == "bad" else 1)
appleDF.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1     1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2     2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3     3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#     Acidity  Quality
# 0 -0.491590        1
# 1 -0.722809        1
# 2  2.621636        0
# 3  0.790723        1
# 4  0.501984        1

# %%
# Split into test and train dataframe
from sklearn.model_selection import train_test_split
columns = ["Size", "Weight", "Sweetness", "Crunchiness", "Juiciness", "Ripeness", "Acidity"]
dfx = appleDF[list(columns)].values
dfy = appleDF["Quality"].values
x_train, x_test, y_train, y_test = train_test_split(dfx, dfy, test_size=0.40, random_state=0)

# %%
print('x_train size = ' + str(x_train.size / 7) +
      '\nx_test size = ' + str(x_test.size / 7) +
      '\ny_train size = ' + str(y_train.size) +
      '\ny_test size = ' + str(y_test.size))
# Out:
# x_train size = 2400.0
# x_test size = 1600.0
# y_train size = 2400
# y_test size = 1600

# %% [markdown]
# # **Decision Tree**

# %%
# Decision Tree
from sklearn import tree
from six import StringIO

clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)
clf_train = clf_train.fit(dfx, dfy)
with open("/content/drive/MyDrive/CPE019_prelim/apple.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns)

print(clf_train.score(x, y))
# Out:
# 0.70475

# %% [markdown]
# The controrl score ratio for the 'all' dataset (unsplitted dataset) shows that the use of the Decision Tree model, gives a score of 70% accuracy between the model and the actual regression

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/CPE019_prelim/appleDT.png")

# %% [markdown]
# The Decision Tree of the Apple Quality dataset indicates that the root node in the Juiciness variable of the Apple indicating that it is the most important factor in indicating the quality of apples. With Size and Ripeness as the 2nd most important variables.

# %%
predict = clf_train.predict(x_test)
testFrame = pd.DataFrame({'Size': x_test[:, 0],
                          'Weight': x_test[:, 1],
                          'Sweetness': x_test[:, 2],
                          'Crunchiness': x_test[:, 3],
                          'Juiciness': x_test[:, 4],
                          'Ripeness': x_test[:, 5],
                          'Acidity': x_test[:, 6],
                          'Quality' : predict})
testFrame.head(10)
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0 -0.882114 -0.630218  -2.350979     1.094072  -2.922815  0.701125 -1.187544
# 1  1.465806 -2.775201   0.992624     1.501921  -1.440469  3.638385  0.352909
# 2 -0.028301  0.673265   0.184109     1.272847   0.925253  0.288045 -1.992565
# 3 -0.984528 -2.011153   0.532582     0.218817   1.686125  0.184332  2.204142
# 4  1.259488 -0.557898  -2.578773    -0.488970   2.581219 -0.232605  0.489467
# 5 -3.308437  1.569101   2.912393    -1.379048   0.897301 -1.421308 -3.997327
# 6 -0.629890 -1.400651  -0.048478    -0.408200   3.898747 -2.742770  0.308678
# 7 -0.408477 -1.150193  -3.031134     0.843985  -2.318131  2.477413 -1.101446
# 8  1.819744 -1.174086  -2.772288    -0.039636  -1.437848  1.648811 -1.098697
# 9  0.273757 -1.723821  -0.376107     0.817061   0.992272 -0.819167  1.293489
#
#    Quality
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# 5        1
# 6        1
# 7        0
# 8        1
# 9        1

# %% [markdown]
# Here we apply the prediction model on the test dataset, showing the decision tree working as it is trained with all input variables in mind.

# %%
# All input variables used
train_score = str(clf_train.score(x_train , y_train))
test_score = str(clf_train.score(x_test , y_test))
print('Training score = '+ train_score+'\nTesting score = '+test_score)
# Out:
# Training score = 0.71375
# Testing score = 0.69125

# %% [markdown]
# The training score shows a 71% accuracy between the model and training dataset and a testing score of 69% accuracy between the model and the testing dataset

# %% [markdown]
# ###**Input Variable Count**
#
# As the Decision Tree indicates the different variables that shows as significant indicators on the quality of apples, how can we say that ALL the input variables show significance between it and indicating the quality of the apples? We can answer this by testing every possible combination of input variables into the model

# %%
# Test function
from sklearn.model_selection import train_test_split
def test(col):
  X = appleDF[list(col)].values
  y = appleDF["Quality"].values
  X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)
  clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)
  clf_train = clf_train.fit(X_train, y_train)
  train_score = clf_train.score(X_train,y_train)
  test_score = clf_train.score(X_test,y_test)
  return (train_score, test_score)

# %%
# Get scores for every possible input variable combination
import itertools
col = ["Size", "Weight", "Sweetness", "Crunchiness", "Juiciness", "Ripeness", "Acidity"]
test_arr = []
for r in range(1, len(col) + 1):
    combinations = itertools.combinations(col, r)
    for combo in combinations:
      val = test(combo)
      test_arr.append([combo, val])
test_arr = np.array(test_arr, dtype="object")

# %%
# Visualize results
import matplotlib.pyplot as plt
import seaborn as sns

input_count, average = [], []
for i in test_arr:
  input_count.append(len(i[0]))
  average.append(np.average(i[1]))

dtResult = pd.DataFrame({'Amount':input_count,
                         'Mean':average})
fig, ax = plt.subplots()
sns.boxplot(x='Amount', y='Mean', data=dtResult, ax=ax)
sns.regplot(x='Amount',
            y='Mean',
            data=dtResult,
            ax = ax,
            scatter=False).set(xlabel='Amount of Input Variables',
                               ylabel='Mean Score',
                               title = 'Regression Line between Input Variable count and Mean Score using Decision Tree')
plt.show()

# %% [markdown]
# Based on the test and score results, there seems to be a very significant relationship between the mean score results of the Decision Tree model, and the amount of Input Variables used in the model training with the Apple quality dataset. In other words, as the amount of input variables are used in the model, the higher average score it gives or the more accurate the model becomes
#
# Although this graph also shows another outlier which is that having 4, 5 or 6 input variables show higher average scores rather than using all input variables.

# %% [markdown]
# ###**Visualizing the Data**

# %% [markdown]
# We can visualize each variable that appears in each combination to determine which variable deems to be the most significant in determining the accuracy of the model.

# %%
def viz_variable(var, title):
  input_count, average = [], []
  for i in test_arr:
    if var in i[0]:
        input_count.append(len(i[0]))
        average.append(np.average(i[1]))

  dtResult = pd.DataFrame({'Amount':input_count,
                          'Mean':average})
  fig, ax = plt.subplots()
  sns.boxplot(x='Amount', y='Mean', data=dtResult, ax=ax)
  sns.regplot(x='Amount',
              y='Mean',
              data=dtResult,
              ax = ax,
              scatter=False).set(xlabel='Amount of Input Variables',
                                ylabel='Mean Score',
                                title = title)
  return x

# %%
reg = []
for i in col:
  text = str('Mean Scores of Combination with "'+i+'"')
  viz_variable(str(i), text)

# %% [markdown]
# A lot of conclusions can be made with the visualization, such as the variable Acidity appears to be significant regardless on the amount of input variables showing low deviations with high mean scores. Or the Juiciness variable being verified to be the most significant variable in terms of it having very low deviating mean scores alongside with 3-5 more other input variables.

# %% [markdown]
# # **Logistic Regression**

# %%
# Logistic Regression
from sklearn import linear_model

logr = linear_model.LogisticRegression()
logr.fit(x_train , y_train)

train_score = str(logr.score(x_train , y_train))
test_score = str(logr.score(x_test , y_test))
print('Training score = '+ train_score+'\nTesting score = '+test_score)
# Out:
# Training score = 0.7583333333333333
# Testing score = 0.73625

# %% [markdown]
# The training score of the Logistic Regression show a 75% ratio whilst the testing score show a 73% ratio

# %%
#Prediction model

predicted = logr.predict(x_test)
testFrame = pd.DataFrame({'Size': x_test[:, 0],
                          'Weight': x_test[:, 1],
                          'Sweetness': x_test[:, 2],
                          'Crunchiness': x_test[:, 3],
                          'Juiciness': x_test[:, 4],
                          'Ripeness': x_test[:, 5],
                          'Acidity': x_test[:, 6],
                          'Quality' : predicted})
testFrame.head(10)
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0 -0.882114 -0.630218  -2.350979     1.094072  -2.922815  0.701125 -1.187544
# 1  1.465806 -2.775201   0.992624     1.501921  -1.440469  3.638385  0.352909
# 2 -0.028301  0.673265   0.184109     1.272847   0.925253  0.288045 -1.992565
# 3 -0.984528 -2.011153   0.532582     0.218817   1.686125  0.184332  2.204142
# 4  1.259488 -0.557898  -2.578773    -0.488970   2.581219 -0.232605  0.489467
# 5 -3.308437  1.569101   2.912393    -1.379048   0.897301 -1.421308 -3.997327
# 6 -0.629890 -1.400651  -0.048478    -0.408200   3.898747 -2.742770  0.308678
# 7 -0.408477 -1.150193  -3.031134     0.843985  -2.318131  2.477413 -1.101446
# 8  1.819744 -1.174086  -2.772288    -0.039636  -1.437848  1.648811 -1.098697
# 9  0.273757 -1.723821  -0.376107     0.817061   0.992272 -0.819167  1.293489
#
#    Quality
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1
# 5        1
# 6        1
# 7        0
# 8        0
# 9        1

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predicted)
print(accuracy)
# Out:
# 0.73625

# %% [markdown]
# Comparing the prediction results of the Logistic Regression to the actual target values, it appears that Logistic Regression classification has a 73.6% accuracy

# %%
fig, ax = plt.subplots()
for var in col:
  sns.regplot(x=var, y='Quality', data=testFrame, logistic=True, ci=None, label=var)

ax.legend()

# %% [markdown]
# The graph shows the logistical curve for each variable compared to the quality. It shows here that the variables Size, Sweetness and Juiciness show a positive S-curve indicating a direct relationship between those variables and the target quality. Whilst the Ripeness variable show a negative S-curve indicating an inverse relationship between the variable and the target quality. The other variables such as Acidity, Weight and Crunchiness show a linear line.

# %% [markdown]
# Reference: https://www.w3schools.com/python/python_ml_logistic_regression.asp

# %% [markdown]
# # **Random Forest**

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split

rf = RandomForestClassifier()
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.885

# %% [markdown]
# Comparing the prediction results of the Random Forest to the actual target values, it appears that Random Forest classification has an astounding 88.5% accuracy

# %%
train_score = str(rf.score(x_train , y_train))
test_score = str(rf.score(x_test , y_test))
print('Training score = '+ train_score+'\nTesting score = '+test_score)
print('Amount of estimators: '+str(len(rf.estimators_)))
# Out:
# Training score = 1.0
# Testing score = 0.885
# Amount of estimators: 100

# %% [markdown]
# The training score of the Random Forest classification shows a ratio of 100%, meaning that the

# %%
# Show first 3 decision trees
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

for i in range(3):
    tree = rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=col,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %% [markdown]
# Random Forest, similar to Decision Tree, creates decision tree for the model to follow to predict the outcome based on input variables. The difference however, is that the Random Forest doesn't only use one, but many trees, which makes it more complex yet more accurate. And similar to the Decision Tree, it still appears that the Juiciness variable is still the root node or the most important variable in determining the quality target.

# %% [markdown]
# References: https://www.datacamp.com/tutorial/random-forests-classifier-python
